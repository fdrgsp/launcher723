# %%
# /// script
# requires-python = ">=3.13"
# dependencies = [
#     "numpy>=2.5.0",
# ]
#
# [pyrunner]
# juv-mode = "exec"  # or "run" (default)
# ///

# %% [markdown]
# # Example Notebook (headless / juv exec)
#
# Replace this notebook with your own. Dependencies are declared in the hidden cell
# above, with a `[pyrunner]` section pinning `juv-mode = "exec"` so pyrunner runs
# every cell headlessly in the terminal instead of opening the Jupyter frontend.
# Use `uvx juv edit example_exec.ipynb` to edit that hidden cell.

# %%
import numpy as np

x = np.linspace(0, 2 * np.pi, 5)
print("Hello from pyrunner!")
print("sin(x) =", np.sin(x))
